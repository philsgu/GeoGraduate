# %%
import pandas as pd
import requests
import streamlit as st
import folium
from folium.plugins import MarkerCluster
from streamlit_folium import folium_static
# Out:
# 2025-03-16 12:05:51.369 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
sheet_url = "https://docs.google.com/spreadsheets/d/1-r0gE0J4HMAOOd0e-sLI_3xbJNtLXFPxUjAh-XlM3OI/edit?usp=sharing"
sheet_id = sheet_url.split("/")[5]
url_sheet = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet=Sheet1"
df = pd.read_csv(url_sheet)

# %%
def extract_lat_long_via_address(address_or_zipcode):
    lat, lng = None, None
    api_key = st.secrets['GOOGLE_GEO_API_KEY']
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    endpoint = f"{base_url}?address={address_or_zipcode}&key={api_key}"
    r = requests.get(endpoint)
    if r.status_code not in range(200, 299):
        return None, None
    try:
        results = r.json()['results'][0]
        lat = results['geometry']['location']['lat']
        lng = results['geometry']['location']['lng']
    except Exception as e:
        print(f"Error processing address '{address_or_zipcode}': {e}")
    return lat, lng

# %%
df['lat'] = df['Employer Full Address'].apply(lambda x: extract_lat_long_via_address(x)[0])
df['lng'] = df['Employer Full Address'].apply(lambda x: extract_lat_long_via_address(x)[1])

# %%
missing_coordinate = df[df['lat'].isna() & df['lng'].isna()]
 #drop NaN and reset index to avoid indexing errors
df.dropna(subset=["lat"])
df.reset_index(drop=True)
# Out:
#    Submission ID Respondent ID         Submitted at  \
# 0         XVOVOg        r1OZYl  2025-03-14 16:35:17
# 1         rN2NZX        r1OZYl  2025-03-14 16:38:00
# 2         LAvZ6J        r1OZYl  2025-03-14 16:48:58
# 3         JaXO9Y        1y4q1b  2025-03-14 17:28:32
# 4         jd5lP1        r1OZYl  2025-03-14 17:29:55
# 5         pjRO08        1y4q1b  2025-03-14 17:39:06
# 6         EjvWAX        1y4q1b  2025-03-14 17:40:26
# 7         9LpDV4        1y4q1b  2025-03-14 17:51:03
# 8         jd5y56        1y4q1b  2025-03-14 17:55:18
# 9         K7vMYk        1y4q1b  2025-03-14 17:59:49
# 10        9LpdRY        1y4q1b  2025-03-14 18:03:16
# 11        VRvldv        1y4q1b  2025-03-14 18:11:45
# 12        2q1kZV        r1OZYl  2025-03-14 18:11:47
# 13        qxoPLG        1y4q1b  2025-03-14 18:14:48
# 14        Qgv0rA        r1OZYl  2025-03-14 18:16:31
# 15        dLKPZD        1y4q1b  2025-03-14 18:17:29
# 16        kDKZjM        r1OZYl  2025-03-14 18:20:14
# 17        2q1LA9        1y4q1b  2025-03-14 18:23:04
# 18        LAvXY1        r1OZYl  2025-03-14 18:24:28
# 19        021LgB        r1OZYl  2025-03-14 18:27:02
# 20        OpdLMR        r1OZYl  2025-03-14 18:28:04
# 21        qxoWbg        r1OZYl  2025-03-14 18:31:13
# 22        VRvYvv        r1OZYl  2025-03-14 18:32:39
# 23        7B19p0        p1Dy6b  2025-03-14 18:47:47
# 24        v7Exvv        p1Dy6b  2025-03-14 18:49:00
# 25        Z4vRBa        p1Dy6b  2025-03-14 18:49:58
# 26        kDK0RJ        r1OZYl  2025-03-14 18:54:25
# 27        e1KN8k        r1OZYl  2025-03-14 18:57:00
# 28        GNXYxz        r1OZYl  2025-03-14 18:59:31
# 29        Opd8Ag        r1OZYl  2025-03-14 19:01:23
# 30        abKZA9        r1OZYl  2025-03-14 19:03:04
# 31        jd5Gp9        r1OZYl  2025-03-14 19:04:13
# 32        zp2W90        r1OZYl  2025-03-14 19:06:13
# 33        YEpp5d        r1OZYl  2025-03-14 19:07:27
# 34        GNXXok        r1OZYl  2025-03-14 19:10:26
# 35        0211G6        r1OZYl  2025-03-14 19:11:30
# 36        NKMbpl        r1OZYl  2025-03-14 19:14:39
# 37        WGDKqv        r1OZYl  2025-03-14 19:18:52
# 38        VRv22M        p1Dy6b  2025-03-14 22:07:13
# 39        e10980        1y4q1b   2025-03-15 1:49:56
# 40        xkR9AJ        1y4q1b   2025-03-15 1:52:00
# 41        8v6ANl        1y4q1b   2025-03-15 1:54:22
#
#                Graduate Full Name Which Graduating Department  \
# 0                 Ugochi Nwokafor                          FM
# 1                Nischint Gondara                          FM
# 2                   Shakeel Ahmad                          FM
# 3                  William Latson                          IM
# 4                     Stella Chan                          FM
# 5                 Parisa Rezapoor                          IM
# 6                  Adam Danielson                          IM
# 7          Bahareh Askari-Atapour                          IM
# 8   Juan Carlos De La Cruz Mayhua                          IM
# 9                     Kevin Orita                          IM
# 10                    Hannah Knox                          IM
# 11              Harkanwal Dhillon                          IM
# 12              Luis Molina Rojas                          FM
# 13                  Imrin Bhinder                          IM
# 14                  Abdul Alcozie                          FM
# 15                      Divya Dev                          IM
# 16                    Andrew Phan                          FM
# 17                      Moon Park                          IM
# 18                        Ena Kim                          FM
# 19               Katarina Soewono                          FM
# 20                 Chinedu Nwagwu                          FM
# 21       Jovanne Tamparon Rosette                          FM
# 22                Malalai Zoltani                          FM
# 23                   Ashley Allen                          EM
# 24                  Hanna Barrett                          EM
# 25                   Adriel Green                          EM
# 26                  Harinder Gill                          FM
# 27                     Alvin Vong                          FM
# 28                    Kal Caldera                          FM
# 29                Prabhneet Singh                          FM
# 30                 Poria Abdollah                          FM
# 31  Maria Lizbeth Alvarado-Garcia                          FM
# 32                 Zhoobin Bateni                          FM
# 33                Farshad Ostovar                          FM
# 34                    Tatum Toner                          FM
# 35                 Greta Jacobsen                          FM
# 36                 Tarnpreet Kaur                          FM
# 37                   Umair Khalid                          FM
# 38                 Tyler Sullivan                          EM
# 39                  Neil Behniwal                          IM
# 40                  Mehrab Devani                          IM
# 41                 Inderbir Baadh                          IM
#
#     Which class year?         Employer Name/Fellowship Program  \
# 0                2024           Primary Care Elica Healthcare
# 1                2024                            Samc Vituity
# 2                2024          Kaiser Permanente Brea Medical
# 3                2024                                     Samc
# 4                2024                    United Health Center
# 5                2021                                     Samc
# 6                2022                                     Samc
# 7                2024                           Samc Im Clinic
# 8                2023        Community Regional Medical Center
# 9                2022               The Medical Partners Group
# 10               2021                 Providence Medical Group
# 11               2023              Community Medical Providers
# 12               2024                                 Altamed
# 13               2023                                     Chpg
# 14               2024                                    Chpg
# 15               2024          Clovis Community Medical Center
# 16               2024                       Kaiser Permanente
# 17               2023               Sleep Medicine Ucsf Fresno
# 18               2024                            Primary Care
# 19               2023              Saint Agnes Medical Center
# 20               2023                            Samc Vituity
# 21               2023                   Stanford Primary Care
# 22               2023                       Samp Primary Care
# 23               2024              Saint Agnes Medical Center
# 24               2024               Saint Agnes Medical Center
# 25               2024               Saint Agnes Medical Center
# 26               2023                       Samp Primary Care
# 27               2022                       Samp Primary Care
# 28               2022  Saint Agnes Sports Medicine Fellowship
# 29               2022                         Chpg Hospitalist
# 30               2022                    Altamed Primary Care
# 31               2022      United Health Centers Primary Care
# 32               2022                      California Urology
# 33               2022                     Vituity Urgent Care
# 34               2022             Hospitalist Sound Physicians
# 35               2022                 Providence Primary Care
# 36               2023                            Sutter Health
# 37               2023                       Samp Primary Care
# 38               2024          Sutter Roseville Medical Center
# 39               2021                     Sutter Medical Group
# 40               2021                                     Samc
# 41               2021                                     Samc
#
#                                 Employer Full Address Work Setting  \
# 0         3701 J St., Suite 201, Sacramento, CA 95816   Ambulatory
# 1               1303 E. Herndon Ave, Fresno, CA 93720     Hospital
# 2                  1900 E. Lambert Rd, Brea, CA 92821   Ambulatory
# 3               1303 E. Herndon Ave, Fresno, CA 93720     Hospital
# 4             3875 W. Beechwood Ave, Fresno, CA 93711   Ambulatory
# 5               1303 E. Herndon Ave, Fresno, CA 93720     Hospital
# 6               1303 E. Herndon Ave, Fresno, CA 93720     Hospital
# 7     7202 N. Millbrook Ave Ste 105, Fresno, CA 93720   Ambulatory
# 8                   2823 Fresno Stm, Fresno, CA 93721     Hospital
# 9                568 E. Herndon Ave, Fresno, CA 93720   Ambulatory
# 10           1162 Montgomery Dr, Santa Rosa, CA 95405   Ambulatory
# 11                   560 E. Herndon, Fresno, CA 93720   Ambulatory
# 12      10418 Valley Blvd. Ste. B, El Monte, CA 91731   Ambulatory
# 13                 2755 Herndon Ave, Clovis, Ca 93611     Hospital
# 14                 2755 Herndon Ave, Clovis, Ca 93611     Hospital
# 15                 2755 Herndon Ave, Clovis, Ca 93611     Hospital
# 16         39400 Paseo Padre Pkwy, Freemont, CA 94538   Ambulatory
# 17                 155 N. Fresno St. Fresno, CA 93701   Fellowship
# 18        12560 PALM DR DESERT, HOT SPRINGS, CA 92240   Ambulatory
# 19              1303 E. Herndon Ave, Fresno, CA 93720   Ambulatory
# 20              1303 E. Herndon Ave, Fresno, CA 93720     Hospital
# 21                 211 Quarry Rd, Palo Alto, CA 94304   Ambulatory
# 22                    2006 Shaw Ave, Clovis, CA 93611   Ambulatory
# 23           1303 E. Herndon Avenue, Fresno, CA 93720     Hospital
# 24           1303 E. Herndon Avenue, Fresno, CA 93720     Hospital
# 25              1303 E. Herndon Ave, Fresno, CA 93720     Hospital
# 26                  1221 Spruce Ave, Fresno, CA 93720   Ambulatory
# 27      2497 Herndon Ave, Suite 102, Clovis, CA 93611   Ambulatory
# 28               1303 E. Herndon Ave Fresno, CA 93720     Hospital
# 29                 2755 Herndon Ave, Clovis, Ca 93611     Hospital
# 30         2661 E Washington Blvd, Pasadena, CA 91107   Ambulatory
# 31                    1545 Mall Dr, Hanford, CA 93230   Ambulatory
# 32  782 Medical Center Drive East Suite 311, Clovi...   Ambulatory
# 33         1780 East Bullard Avenue, Fresno, CA 93710   Ambulatory
# 34         2827 Fort Missoula Rd, Missoula, MT, 59804     Hospital
# 35  1821 Wilshire Blvd STE 100, Santa Monica, CA 9...   Ambulatory
# 36      3100 W Christoffersen Pkwy, Turlock, CA 95382   Ambulatory
# 37                    2006 Shaw Ave, Clovis, CA 93611   Ambulatory
# 38            1 Medical Plaza Dr, Roseville, CA 95661     Hospital
# 39                  818 38th St, Sacramento, CA 95816   Ambulatory
# 40               1303 E. Herndon Ave Fresno, CA 93720     Hospital
# 41              1303 E. Herndon ave. Fresno, CA 93720     Hospital
#
#                           Resident GME Headshot image        lat         lng
# 0   https://storage.tally.so/private/Ugochi-Nwokaf...  38.571019 -121.456582
# 1   https://storage.tally.so/private/Nischint-Gond...  36.833966 -119.764263
# 2   https://storage.tally.so/private/Shakeel-Ahmad...  33.924597 -117.876283
# 3   https://storage.tally.so/private/William-Latso...  36.833966 -119.764263
# 4   https://storage.tally.so/private/Dr.-Stella-Ch...  36.837962 -119.863073
# 5   https://storage.tally.so/private/Parisa-Rezapo...  36.833966 -119.764263
# 6   https://storage.tally.so/private/Danielson.pho...  36.833966 -119.764263
# 7   https://storage.tally.so/private/Bahareh-Askar...  36.839955 -119.764377
# 8   https://storage.tally.so/private/Juan-Carlos-D...  36.742951 -119.784230
# 9   https://storage.tally.so/private/Kevin-Orita.J...  36.838726 -119.777482
# 10  https://storage.tally.so/private/Hannah-Knox.j...  38.443033 -122.700182
# 11  https://storage.tally.so/private/Harkanwal-Kau...  36.837906 -119.777915
# 12  https://storage.tally.so/private/Luis-Molina.j...  34.076075 -118.045908
# 13  https://storage.tally.so/private/Imrin-Sidhu.j...  36.838847 -119.661183
# 14  https://storage.tally.so/private/Abdul-Alcozie...  36.838847 -119.661183
# 15  https://storage.tally.so/private/Divya-Dev-IM-...  36.838847 -119.661183
# 16  https://storage.tally.so/private/Andrew-Phan.j...  37.552032 -121.976118
# 17  https://storage.tally.so/private/Moon-Park-IM-...  36.743524 -119.782358
# 18  https://storage.tally.so/private/Ena-Kim.jpg?i...  33.957300 -116.500845
# 19  https://storage.tally.so/private/Katarina-Soew...  36.833966 -119.764263
# 20  https://storage.tally.so/private/Chinedu-Nwagw...  36.833966 -119.764263
# 21  https://storage.tally.so/private/Jovanne-Tampa...  37.441452 -122.168733
# 22  https://storage.tally.so/private/Malalai-Zolta...  36.808229 -119.677213
# 23  https://storage.tally.so/private/Ashley-Allen-...  36.833966 -119.764263
# 24  https://storage.tally.so/private/Hanna-Barrett...  36.833966 -119.764263
# 25  https://storage.tally.so/private/Adriel-Green-...  36.833966 -119.764263
# 26  https://storage.tally.so/private/Harinder-Gill...  36.841648 -119.761681
# 27  https://storage.tally.so/private/Alvin-Vong-FM...  36.837734 -119.666517
# 28  https://storage.tally.so/private/Kal-Caldera-F...  36.833966 -119.764263
# 29  https://storage.tally.so/private/Prabhneet-K-S...  36.838847 -119.661183
# 30  https://storage.tally.so/private/Poria-Abdolla...  34.169507 -118.095488
# 31  https://storage.tally.so/private/Maria-Lizbeth...  36.322825 -119.669576
# 32  https://storage.tally.so/private/Zhoobin-Baten...  36.842675 -119.659907
# 33  https://storage.tally.so/private/Farshad-Ostov...  36.823501 -119.754477
# 34  https://storage.tally.so/private/Tatum-Toner-F...  46.847674 -114.048699
# 35  https://storage.tally.so/private/Greta-Jacobse...  34.030652 -118.484765
# 36  https://storage.tally.so/private/Tarnpreet-Kau...  37.528462 -120.883895
# 37  https://storage.tally.so/private/Umair-Khalid-...  36.808229 -119.677213
# 38  https://storage.tally.so/private/Tyler-Sulliva...  38.766251 -121.249223
# 39  https://storage.tally.so/private/Neilinder-Beh...  38.572279 -121.455728
# 40  https://storage.tally.so/private/Mehrab-Devani...  36.833966 -119.764263
# 41  https://storage.tally.so/private/Inderbir-Baad...  36.833966 -119.764263

# %%
df['Graduate Full Name'] = df['Graduate Full Name'].str.strip()
df['Graduate Full Name'] = df['Graduate Full Name'].str.title()
df['Employer Name/Fellowship Program'] = df['Employer Name/Fellowship Program'].str.title()

# %%
df.columns
# Out:
# Index(['Submission ID', 'Respondent ID', 'Submitted at', 'Graduate Full Name',
#        'Which Graduating Department', 'Which class year?',
#        'Employer Name/Fellowship Program', 'Employer Full Address',
#        'Work Setting', 'Resident GME Headshot image', 'lat', 'lng'],
#       dtype='object')

# %%
df['Resident GME Headshot image'].iloc[0]
# Out:
# 'https://storage.tally.so/private/Ugochi-Nwokafor.jpg?id=g0Bx6J&accessToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6ImcwQng2SiIsImZvcm1JZCI6IjNFTU15NCIsImlhdCI6MTc0MjA2ODY3NX0.lB5OEPfPLIfsRmCedshk40hY8Qp9dM2-ZxMv34uNt-g&signature=b886b3d7b2c4f7caa8266052201f2ff96fa2cf4cbc75d5339a339d7dd178ad3a'

# %%
df['Work Setting'].unique()
# Out:
# array(['Ambulatory', 'Hospital', 'Fellowship'], dtype=object)

# %%
def popup_html(row):
    i = row
    grad_name=df['Graduate Full Name'].iloc[i]
    grad_year=df['Graduation Year'].iloc[i]
    grad_dept=df['Which Graduating Department'].iloc[i]
    grad_employer=df['Employer Name/Fellowship Program'].iloc[i]
    grad_work_setting=df['Work Setting'].iloc[i]
    grad_url_image = df['Resident GME Headshot image'].iloc[i]
    grad_image_html = f'<center><img src={grad_url_image} alt="logo" width=100 height=100></center>'

    
    left_col_color = "#3e95b5"
    right_col_color = "#f2f9ff"

    html = f"""
        <!DOCTYPE html>
        <html>
        {grad_image_html} 
        <center><h4 style="margin-bottom:5"; width="200px">{grad_name}</h4></center>

        <center>
        <table style="height: 126px; width: 305px;">
        
        <tbody>
        <tr>
        <td style="background-color: {left_col_color}; padding: 5px"><span style="color: #ffffff;"> Graduate Year </span></td>
        <td style="width: 150px;background-color: {right_col_color}; padding: 5px">{grad_year}</td>
        </tr>
        
        <tr>
        <td style="background-color: {left_col_color}; padding: 5px"><span style="color: #ffffff;"> Department </span></td>
        <td style="width: 150px;background-color: {right_col_color}; padding: 5px">{grad_dept}</td>
        </tr>
        
        <tr>
        <td style="background-color: {left_col_color}; padding: 5px"><span style="color: #ffffff;"> Employer </span></td>
        <td style="width: 150px;background-color: {right_col_color}; padding: 5px">{grad_employer}</td>
        </tr>
        
        <tr>
        <td style="background-color: {left_col_color}; padding: 5px"><span style="color: #ffffff;"> Work Setting </span></td>
        <td style="width: 150px;background-color: {right_col_color}; padding: 5px">{grad_work_setting}</td>
        </tr>
        </tbody>
        </table>
        </center>
        </html>
        """ 
    return html

# %%
#create a functiont to show and downloand map html data 
def show_map():
    m = folium.Map(location=df[["lat", "lng"]].mean().to_list(), zoom_start=2)
    # if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
    marker_cluster = MarkerCluster().add_to(m)
    # draw the markers and assign popup and hover texts
    # add the markers the the cluster layers so that they are automatically cluster
    for i,r in df.iterrows():
        location = (r["lat"], r["lng"])
        # highlight differtn work settings with different colors 
        worksetting = df['Work Setting'].iloc[i]
        if worksetting == "Ambulatory":
            color = "green"
            tooltip = "Ambulatory"
        elif worksetting == "Hospital":
            color = "red"
            tooltip = "Hospital"
        elif worksetting == "Fellowship":
            color = "blue"
            tooltip = "Fellowship"
        else:
            color = "black"
            tooltip = "Other"
        
        folium.Marker(location=location, popup=popup_html(i), tooltip=tooltip, icon=folium.Icon(color=color, icon='user', prefix='fa')).add_to(marker_cluster)

    m.save("geo_applicants.html")
    folium_static(m, width=725)
    with open("geo_applicants.html", "r") as file:
        st.markdown(file.read(), unsafe_allow_html=True)
